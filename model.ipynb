# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Visadataset.csv")

# %%
df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %% [markdown]
# #check the null value

# %%
feature_with_na=[feature for feature in df.columns if df[feature].isnull().sum()>1]

# %%
feature_with_na
# Out:
# []

# %%
#no null values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
ohec=["full_time_position","continent","unit_of_wage","region_of_employment","has_job_experience","requires_job_training"]
orec=["education_of_employee"]
scc=["prevailing_wage","no_of_employees"]

# %%
df.drop('case_id',inplace=True,axis=1)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder,StandardScaler,OrdinalEncoder,PowerTransformer

# %%
from math import remainder
from types import SimpleNamespace
transformer=ColumnTransformer(transformers=[
    ("OneHotencoder",OneHotEncoder(),ohec),
    ("ordinalencoder",OrdinalEncoder(),orec)

])

# %%
from sklearn.pipeline import Pipeline
pipeline=Pipeline(steps=[
    ("transformer",transformer),
    ("classifier",DecisionTreeClassifier())
])

# %%
x=df.drop('case_status',axis=1)
y=df['case_status']

# %%
y=np.where(y=='Denied',0,1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape,x_test.shape
# Out:
# ((20384, 10), (5096, 10))

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
pipeline.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('transformer',
#                  ColumnTransformer(transformers=[('OneHotencoder',
#                                                   OneHotEncoder(),
#                                                   ['full_time_position',
#                                                    'continent', 'unit_of_wage',
#                                                    'region_of_employment',
#                                                    'has_job_experience',
#                                                    'requires_job_training']),
#                                                  ('ordinalencoder',
#                                                   OrdinalEncoder(),
#                                                   ['education_of_employee'])])),
#                 ('classifier', DecisionTreeClassifier())])

# %%
y_train_pred=pipeline.predict(x_train)
y_test_pred=pipeline.predict(x_test)

# %%
y_train_pred
# Out:
# array([0, 1, 0, ..., 1, 1, 1])

# %%
y_train
# Out:
# array([0, 0, 1, ..., 1, 1, 1])

# %%
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_test,y_test_pred)
print(accuracy)
# Out:
# 0.7533359497645212

# %%
accuracy=accuracy_score(y_train,y_train_pred)
print(accuracy)
# Out:
# 0.7626079277864992

# %%
import pickle

pickle_model_path="model.pkl"
with open(pickle_model_path,'wb') as f:
    pickle.dump(pipeline,f)
